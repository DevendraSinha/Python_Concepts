# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import binom
# to ignore the warnings
from warnings import filterwarnings

# %%
df=pd.read_csv("/content/customer_churn.csv")

# %%
sns.pairplot(df, hue ='Churn',kind='hist')

# %%
x = df['Churn']
r_values=x.to_list()

# %%
y=binom.pmf(x, )
#y = poisson.pmf(x, mu=50, loc=0)

# %%
#dist = [binom.pmf(r,900,0.80) for r in x ]
dist =[binom.pmf(r, 900, 0.80) for r in r_values ]
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-15-b3f17d4442c7> in <cell line: 2>()
#       1 #dist = [binom.pmf(r,900,0.80) for r in x ]
# ----> 2 dist =[binom.pmf(r, 900, 0.80) for r in r_values ]
#
# <ipython-input-15-b3f17d4442c7> in <listcomp>(.0)
#       1 #dist = [binom.pmf(r,900,0.80) for r in x ]
# ----> 2 dist =[binom.pmf(r, 900, 0.80) for r in r_values ]
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_distn_infrastructure.py in pmf(self, k, *args, **kwds)
#    3366         args = tuple(map(asarray, args))
#    3367         _a, _b = self._get_support(*args)
# -> 3368         k = asarray(k-loc)
#    3369         cond0 = self._argcheck(*args)
#    3370         cond1 = (k >= _a) & (k <= _b)
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U3'), dtype('int64')) -> None
