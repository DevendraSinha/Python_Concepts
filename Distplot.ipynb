# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import binom
# to ignore the warnings
from warnings import filterwarnings

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.shape
# Out:
# (244, 7)

# %%
df.mean(), df.median(),df.mode()
# Out:
# <ipython-input-16-e2b35095af4a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean(), df.median(),df.mode()
# <ipython-input-16-e2b35095af4a>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean(), df.median(),df.mode()
# (total_bill    19.785943
#  tip            2.998279
#  size           2.569672
#  dtype: float64,
#  total_bill    17.795
#  tip            2.900
#  size           2.000
#  dtype: float64,
#     total_bill  tip   sex smoker  day    time  size
# ...

# %%
dt=df['tip'].to_list()
#pm=
pr=[binom.pmf(r, 245, 0.8) for r in dt ]
plt.bar(dt, pr)
# Out:
# <BarContainer object of 244 artists>

# %%
data = {

    "Tip": dt,

    "Probab": pr

}
df1 = pd.DataFrame(data)
df1

# %% [markdown]
# #Distplot

# %%
sns.displot(x=df['tip'],kde = True, color ='violet', bins = 30)

# %%
sns.displot(x=df['total_bill'],kde = True, color ='blue', bins = 30)

# %%
sns.jointplot(x ='total_bill', y ='tip', data = df)

# %%
sns.jointplot(x ='total_bill', y ='tip', data = df, kind ='kde')
# KDE shows the density where the points match up the most

# %%
# pairplot with hue sex
sns.pairplot(df, hue ='sex')
# to show
plt.show()

# %%
sns.distplot(np.random.binomial(n=100, p=0.6, size=1000), hist=True,kde=True, label='binomial')
# Out:
# <ipython-input-41-4cd7b867b705>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.binomial(n=100, p=0.6, size=1000), hist=True,kde=True, label='binomial')
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df, hue ='day',kind='kde')
# to show
plt.show()
