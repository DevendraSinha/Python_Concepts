# %%
! pip install PandasAI
# !pip install pandasai
# !pip install google.generativeai

# %%
import pandas as pd
import numpy as np
from pandasai import SmartDataframe
from pandasai.llm import GooglePalm
import os
import google.generativeai as genai
from IPython.display import HTML, Markdown, display
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Markdown
import textwrap

# %%
import pandas as pd
import numpy as np
import pandasai as pai
from pandasai.llm.openai import OpenAI

# %%
df = pd.DataFrame({
    "Customer": ["Cust1", "Cust2", "Cust3", "Cust4", "Cust5", "Cust6", "Cust7", "Cust8", "Cust8"],
    "Sales_Quantity": [12, 14, np.nan, 16, 18, 25, 29, 45, 45],
    "Sales_Amount": [35678, 45678, 6739,np.nan ,67892, 25638, 35689, 85278, 85278]
})

# %%
os.environ['GOOGLE_API_KEY'] = 'AIzaSyDi0iOBqYGA-jwCf3O93On2bUvBK9gdJGg' # Replace YOUR_API_KEY with your actual key
google_api_key = os.environ.get('GOOGLE_API_KEY')
genai.configure(api_key=google_api_key)

# %%
df
# Out:
#   Customer  Sales_Quantity  Sales_Amount
# 0    Cust1            12.0       35678.0
# 1    Cust2            14.0       45678.0
# 2    Cust3             NaN        6739.0
# 3    Cust4            16.0           NaN
# 4    Cust5            18.0       67892.0
# 5    Cust6            25.0       25638.0
# 6    Cust7            29.0       35689.0
# 7    Cust8            45.0       85278.0
# 8    Cust8            45.0       85278.0

# %%
user_secrets = UserSecretsClient()
apiKey = user_secrets.get_secret("Gemini_API")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-81778ce04fbf> in <cell line: 1>()
# ----> 1 user_secrets = UserSecretsClient()
#       2 apiKey = user_secrets.get_secret("Gemini_API")
#
# NameError: name 'UserSecretsClient' is not defined

# %%
response = pandasai.pandas(df, "Any duplicates in data and display Customer")
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-82cab8cbab92> in <cell line: 1>()
# ----> 1 response = pandasai.pandas(df, "Any duplicates in data and display Customer")
#       2 print(response)
#
# TypeError: 'module' object is not callable
