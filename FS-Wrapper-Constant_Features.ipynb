# %% [markdown]
# #Feature Selection- Filter Method
#
# 1.   Constant Features
# 2.   Quasi Constant Features
# 3.   Duplicated Features

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# # Constant Features

# %%
dataset=pd.read_csv("/content/dataset_1.csv")

# %%
dataset.shape
# Out:
# (50000, 301)

# %%
dataset.info()

# %% [markdown]
# #Split Dataset into Test and Train

# %%
X=dataset.drop('target',axis=1)
y=dataset['target']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((40000, 300), (10000, 300))

# %% [markdown]
# #Using VarianceThreshold from Scikit-learn

# %%
sel = VarianceThreshold(threshold=0)
sel.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
mask=sel.get_support()
constant = X_train.columns[~sel.get_support()]

# %%
feat=X_train.columns[sel.get_support()]

# %%
X_train = sel.transform(X_train)
X_test = sel.transform(X_test)
X_train.shape, X_test.shape
# Out:
# ((40000, 266), (10000, 266))

# %% [markdown]
# #Using Pandas Dataframe
#
# *   std()
# *   nunique()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
constant_features=[cols for cols in  X_train.columns if X_train[cols].std()==0]
print(len(constant_features))
# Out:
# 34

# %%
X_train=X_train.astype("O")

# %%
constant_features=[cols for cols in  X_train.columns if X_train[cols].nunique()==1]
print(len(constant_features))
# Out:
# 34

# %% [markdown]
# # Quasi Constant Features

# %%
X_train=pd.DataFrame(X_train)

# %%
sel = VarianceThreshold(threshold=0.01)
sel.fit(X_train)
# Out:
# VarianceThreshold(threshold=0.01)

# %%
feat=X_train.columns[~sel.get_support()]
print(feat)

# %%
X_train=sel.transform(X_train)

# %%
X_test=sel.transform(X_test)

# %%
X_train.shape,X_test.shape
# Out:
# ((40000, 218), (10000, 218))

# %% [markdown]
# # Duplicate Features
