# %% [markdown]
# #Feature Engineering : Standardization and Scaling
#  # Date: 02-09-2022

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
a = np.random.randint(10, size=(10,1))
b = np.random.randint(50, 100, size=(10,1))
c = np.random.randint(500, 700, size=(10,1))
X = np.concatenate((a,b,c), axis=1)
X
# Out:
# array([[  5,  57, 614],
#        [  6,  82, 663],
#        [  0,  80, 525],
#        [  9,  60, 629],
#        [  9,  98, 567],
#        [  6,  90, 582],
#        [  7,  71, 568],
#        [  0,  92, 666],
#        [  8,  95, 577],
#        [  0,  72, 589]])

# %% [markdown]
# # Mean and Std before Scaling

# %%
X.mean(axis=0)
# Out:
# array([  5. ,  79.7, 598. ])

# %%
X.std(axis=0)
# Out:
# array([ 3.49284984, 13.67515996, 42.46645735])

# %% [markdown]
# # Mean and STD after standrdization

# %%
sc = preprocessing.StandardScaler().fit(X)

# %%
X_standardized = sc.transform(X)

# %%
X_standardized.mean(axis=0)
# Out:
# array([-2.22044605e-17, -2.22044605e-16,  1.38777878e-17])

# %%
X_standardized.std(axis=0)
# Out:
# array([1., 1., 1.])
