# %%
# prompt: get google_api_key

import os
# Replace with your actual API key
os.environ['GOOGLE_API_KEY'] = 'devendra'
google_api_key = os.environ.get('GOOGLE_API_KEY')
print(google_api_key)

# Please be aware of security implications of hardcoding API keys. Consider using more secure methods.
# Out:
# devendra

# %%
import google.generativeai as genai
from IPython.display import HTML, Markdown, display

# %%
flash = genai.GenerativeModel('gemini-1.5-flash')
response = flash.generate_content("Explain AI to me like I'm a kid.")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-5-41a54f63f2a2> in <cell line: 2>()
#       1 flash = genai.GenerativeModel('gemini-1.5-flash')
# ----> 2 response = flash.generate_content("Explain AI to me like I'm a kid.")
#       3 print(response.text)
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# ...

# %%
# prompt: GenerativeModel

import os
import google.generativeai as genai
from IPython.display import HTML, Markdown, display

# Replace with your actual API key.  Do not hardcode API keys in production code.
# Consider using environment variables or a more secure secret management system.
os.environ['GOOGLE_API_KEY'] = 'AIzaSyDi0iOBqYGA-jwCf3O93On2bUvBK9gdJGg' # Replace YOUR_API_KEY with your actual key
google_api_key = os.environ.get('GOOGLE_API_KEY')

genai.configure(api_key=google_api_key)

# Use a try-except block to handle potential errors during API calls
try:
    # Specify the model you want to use
    model = genai.GenerativeModel('gemini-pro')

    # Generate content using the specified model and prompt
    response = model.generate_content("How to prepare for Time Series Analysis")
    print(response.text)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# **1. Understand Time Series Concepts:**
#
# * Time series structure and components
# * Seasonality, trends, and stationarity
# * Autocorrelation and partial autocorrelation
#
# **2. Master Statistical Techniques:**
#
# * Descriptive statistics (mean, median, variance)
# * Probability distributions (normal, t-distribution)
# * Hypothesis testing and confidence intervals
#
# **3. Learn Time Series Models:**
#
# * **Autoregressive integrated moving average (ARIMA)**
# * **Exponential smoothing (ETS)**
# * **Structural time series models (STSM)**
#
# **4. Choose Appropriate Time Series Models:**
#
# * Identify seasonality, trends, and stationarity
# * Use model selection criteria (AIC, BIC)
# * Validate models using cross-validation and diagnostic tests
#
# **5. Forecast Time Series:**
#
# * Make point and interval forecasts
# * Evaluate forecast accuracy and uncertainty
#
# **6. Implement Time Series Analysis in Software:**
#
# ...
