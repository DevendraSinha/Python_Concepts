# %% [markdown]
# # Regular Expressions

# %% [markdown]
# #1. findall

# %%
import re
base_str="Hello my Number is 123456789 and my friend's number is 987654321"
# Finding all the Occurences of digit of length 1 or more than 1.
regex = '\d+' 
op=re.findall(regex,base_str)
print(op)
# Out:
# ['123456789', '987654321']

# %% [markdown]
# # 2. compile()

# %%
import re
p=re.compile('[a-e]')
base_str="Aye, said Mr. Gibenson Stark"
op=p.findall(base_str)
print(op)
# search all alphanumeric Characters 
p=re.compile('\w')
print(p.findall("He said * in some_lang."))
# search all alphanumeric Characters of length 1 or more than one 
p=re.compile('\w+')
print(p.findall("He said * in some_lang."))
# search all Non alphanumeric Characters 
p=re.compile('\W')
print(p.findall("He said * in some_lang."))
# search all Non alphanumeric Characters of length 1 or more than one 
p=re.compile('\W+')
print(p.findall("He said * in some_lang."))
# Out:
# ['e', 'a', 'd', 'b', 'e', 'a']
# ['H', 'e', 's', 'a', 'i', 'd', 'i', 'n', 's', 'o', 'm', 'e', '_', 'l', 'a', 'n', 'g']
# ['He', 'said', 'in', 'some_lang']
# [' ', ' ', '*', ' ', ' ', '.']
# [' ', ' * ', ' ', '.']

# %% [markdown]
# # Split

# %%
from re import split
 
# '\W+' denotes Non-Alphanumeric Characters
# or group of characters Upon finding ','
# or whitespace ' ', the split(), splits the
# string from that point
print(split('\W+', 'Words, words , Words'))
print(split('\W+', "Word's words Words"))
 
# Here ':', ' ' ,',' are not AlphaNumeric thus,
# the point where splitting occurs
print(split('\W+', 'On 12th Jan 2016, at 11:02 AM'))
 
# '\d+' denotes Numeric Characters or group of
# characters Splitting occurs at '12', '2016',
# '11', '02' only
print(split('\d+', 'On 12th Jan 2016, at 11:02 AM'))
# Out:
# ['Words', 'words', 'Words']
# ['Word', 's', 'words', 'Words']
# ['On', '12th', 'Jan', '2016', 'at', '11', '02', 'AM']
# ['On ', 'th Jan ', ', at ', ':', ' AM']

# %%
import re
print(re.subn('ub', '~*', 'Subject has Uber booked already'))
t = re.subn('ub', '~*', 'Subject has Uber booked already',flags=re.IGNORECASE)
print(t)
print(len(t))

# This will give same output as sub() would have
print(t[0])
print(t[1])
# Out:
# ('S~*ject has Uber booked already', 1)
# ('S~*ject has ~*er booked already', 2)
# 2
# S~*ject has ~*er booked already
# 2

# %%
import re
#use a regular expression to match a date string
# in the form of Month name followed by day number
regex=r"([a-zA-Z]+) (\d+)"
#regex = r"([a-zA-Z]+) (\d+)"
match=re.search(regex,"I was born on June 24")
if match!=None:
    print ("Match at index %s, %s" % (match.start(), match.end()))
 # match.group(0) always returns the fully matched string
 # match.group(1) match.group(2), ... return the capture
 # groups in order from left to right in the input string
 # match.group() is equivalent to match.group(0)
    print ("Full match: %s" % (match.group(0)))
    # So this will print "June"
    print ("Month: %s" % (match.group(1)))
    # So this will print "24"
    print ("Day: %s" % (match.group(2)))
# Out:
# Match at index 14, 21
# Full match: June 24
# Month: June
# Day: 24

# %%
import re
 
s = "Welcome to GeeksForGeeks"
 
# here x is the match object
res = re.search(r"Gee", s)
 
print(res.start())
print(res.end())
print(res.span())
# Out:
# 11
# 14
# (11, 14)
