# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
#  # Use Case 1:Hourly Energy Comsumption

# %%
df=pd.read_csv("/content/PJME_hourly.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145366 entries, 0 to 145365
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  145366 non-null  object
#  1   PJME_MW   145366 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#              PJME_MW
# count  145366.000000
# mean    32080.222831
# std      6464.012166
# min     14544.000000
# 25%     27573.000000
# 50%     31421.000000
# 75%     35650.000000
# max     62009.000000

# %%
df.head(40)
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# Datetime
# 2002-12-31 01:00:00  26498.0     1          1        4     12  2002
# 2002-12-31 02:00:00  25147.0     2          1        4     12  2002
# 2002-12-31 03:00:00  24574.0     3          1        4     12  2002
# 2002-12-31 04:00:00  24393.0     4          1        4     12  2002
# 2002-12-31 05:00:00  24860.0     5          1        4     12  2002
# 2002-12-31 06:00:00  26222.0     6          1        4     12  2002
# 2002-12-31 07:00:00  28702.0     7          1        4     12  2002
# 2002-12-31 08:00:00  30698.0     8          1        4     12  2002
# 2002-12-31 09:00:00  31800.0     9          1        4     12  2002
# 2002-12-31 10:00:00  32359.0    10          1        4     12  2002
# 2002-12-31 11:00:00  32371.0    11          1        4     12  2002
# 2002-12-31 12:00:00  31902.0    12          1        4     12  2002
# 2002-12-31 13:00:00  31126.0    13          1        4     12  2002
# 2002-12-31 14:00:00  30368.0    14          1        4     12  2002
# 2002-12-31 15:00:00  29564.0    15          1        4     12  2002
# 2002-12-31 16:00:00  29098.0    16          1        4     12  2002
# 2002-12-31 17:00:00  30308.0    17          1        4     12  2002
# 2002-12-31 18:00:00  34017.0    18          1        4     12  2002
# 2002-12-31 19:00:00  34195.0    19          1        4     12  2002
# 2002-12-31 20:00:00  32790.0    20          1        4     12  2002
# 2002-12-31 21:00:00  31336.0    21          1        4     12  2002
# 2002-12-31 22:00:00  29887.0    22          1        4     12  2002
# 2002-12-31 23:00:00  28483.0    23          1        4     12  2002
# 2003-01-01 00:00:00  27008.0     0          2        1      1  2003
# 2002-12-30 01:00:00  27526.0     1          0        4     12  2002
# 2002-12-30 02:00:00  26600.0     2          0        4     12  2002
# 2002-12-30 03:00:00  26241.0     3          0        4     12  2002
# 2002-12-30 04:00:00  26213.0     4          0        4     12  2002
# 2002-12-30 05:00:00  26871.0     5          0        4     12  2002
# 2002-12-30 06:00:00  28679.0     6          0        4     12  2002
# 2002-12-30 07:00:00  31509.0     7          0        4     12  2002
# 2002-12-30 08:00:00  33665.0     8          0        4     12  2002
# 2002-12-30 09:00:00  34625.0     9          0        4     12  2002
# 2002-12-30 10:00:00  34655.0    10          0        4     12  2002
# 2002-12-30 11:00:00  34295.0    11          0        4     12  2002
# 2002-12-30 12:00:00  33711.0    12          0        4     12  2002
# 2002-12-30 13:00:00  33087.0    13          0        4     12  2002
# 2002-12-30 14:00:00  32668.0    14          0        4     12  2002
# 2002-12-30 15:00:00  32380.0    15          0        4     12  2002
# 2002-12-30 16:00:00  32484.0    16          0        4     12  2002
#
#                      dayofyear  dayofmonth  weekofyear
# Datetime
# 2002-12-31 01:00:00        365          31           1
# 2002-12-31 02:00:00        365          31           1
# 2002-12-31 03:00:00        365          31           1
# 2002-12-31 04:00:00        365          31           1
# 2002-12-31 05:00:00        365          31           1
# 2002-12-31 06:00:00        365          31           1
# 2002-12-31 07:00:00        365          31           1
# 2002-12-31 08:00:00        365          31           1
# 2002-12-31 09:00:00        365          31           1
# 2002-12-31 10:00:00        365          31           1
# 2002-12-31 11:00:00        365          31           1
# 2002-12-31 12:00:00        365          31           1
# 2002-12-31 13:00:00        365          31           1
# 2002-12-31 14:00:00        365          31           1
# 2002-12-31 15:00:00        365          31           1
# 2002-12-31 16:00:00        365          31           1
# 2002-12-31 17:00:00        365          31           1
# 2002-12-31 18:00:00        365          31           1
# 2002-12-31 19:00:00        365          31           1
# 2002-12-31 20:00:00        365          31           1
# 2002-12-31 21:00:00        365          31           1
# 2002-12-31 22:00:00        365          31           1
# 2002-12-31 23:00:00        365          31           1
# 2003-01-01 00:00:00          1           1           1
# 2002-12-30 01:00:00        364          30           1
# 2002-12-30 02:00:00        364          30           1
# 2002-12-30 03:00:00        364          30           1
# 2002-12-30 04:00:00        364          30           1
# 2002-12-30 05:00:00        364          30           1
# 2002-12-30 06:00:00        364          30           1
# 2002-12-30 07:00:00        364          30           1
# 2002-12-30 08:00:00        364          30           1
# 2002-12-30 09:00:00        364          30           1
# 2002-12-30 10:00:00        364          30           1
# 2002-12-30 11:00:00        364          30           1
# 2002-12-30 12:00:00        364          30           1
# 2002-12-30 13:00:00        364          30           1
# 2002-12-30 14:00:00        364          30           1
# 2002-12-30 15:00:00        364          30           1
# 2002-12-30 16:00:00        364          30           1

# %%
df = df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %%
df.plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='PJME Energy Use in MW')
#plt.show()
# Out:
# <Axes: title={'center': 'PJME Energy Use in MW'}, xlabel='Datetime'>

# %%
df.loc[(df.index > '01-01-2010') & (df.index < '01-31-2010')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='hour', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='PJME_MW', palette='Blues')
ax.set_title('MW by Month')
plt.show()
# Out:
# <ipython-input-25-69cf918e87c9>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='month', y='PJME_MW', palette='Blues')

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='year', y='PJME_MW', palette='Blues')
ax.set_title('MW by Day of Week')
plt.show()
# Out:
# <ipython-input-34-4b6c58d40d2f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='year', y='PJME_MW', palette='Blues')

# %%
df.year.min(),df.year.max()
# Out:
# (2002, 2018)
